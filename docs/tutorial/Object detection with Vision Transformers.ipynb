# %% [markdown]
# # Object detection

# %% [markdown]
# ## single machine

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python -m pip install -U tensorflow-addons
# !python -m pip install -U opencv-python
# Out:
# Requirement already satisfied: tensorflow-addons in /home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages (0.21.0)
# Requirement already satisfied: packaging in /home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages (from tensorflow-addons) (23.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: opencv-python in /home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.17.0 in /home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages (from opencv-python) (1.23.5)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import scipy.io
import shutil
# Out:
# 2023-09-02 11:53:06.992318: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-02 11:53:07.807508: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-09-02 11:53:07.807603: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-09-02 11:53:07.807614: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# Path to images and annotations
path_images = "./101_ObjectCategories/airplanes/"
path_annot = "./Annotations/Airplanes_Side_2/"

path_to_downloaded_file = keras.utils.get_file(
    fname="caltech_101_zipped",
    origin="https://data.caltech.edu/records/mzrjq-6wc02/files/caltech-101.zip",
    extract=True,
    archive_format="zip",  # downloaded file format
    cache_dir="/",  # cache and extract in current directory
)

# Extracting tar files found inside main zip file
shutil.unpack_archive("./datasets/caltech-101/101_ObjectCategories.tar.gz", "./")
shutil.unpack_archive("./datasets/caltech-101/Annotations.tar", "./")

# list of paths to images and annotations
image_paths = [
    f for f in os.listdir(path_images) if os.path.isfile(os.path.join(path_images, f))
]
annot_paths = [
    f for f in os.listdir(path_annot) if os.path.isfile(os.path.join(path_annot, f))
]

image_paths.sort()
annot_paths.sort()

image_size = 224  # resize input images to this size

images, targets = [], []

# loop over the annotations and images, preprocess them and store in lists
for i in range(0, len(annot_paths)):
    # Access bounding box coordinates
    annot = scipy.io.loadmat(path_annot + annot_paths[i])["box_coord"][0]

    top_left_x, top_left_y = annot[2], annot[0]
    bottom_right_x, bottom_right_y = annot[3], annot[1]

    image = keras.utils.load_img(
        path_images + image_paths[i],
    )
    (w, h) = image.size[:2]

    # resize train set images
    if i < int(len(annot_paths) * 0.8):
    # resize image if it is for training dataset
        image = image.resize((image_size, image_size))

    # convert image to array and append to list
    images.append(keras.utils.img_to_array(image))

    # apply relative scaling to bounding boxes as per given image and append to list
    targets.append(
        (
            float(top_left_x) / w,
            float(top_left_y) / h,
            float(bottom_right_x) / w,
            float(bottom_right_y) / h,
        )
    )

# Convert the list to numpy array, split to train and test dataset
(x_train), (y_train) = (
    np.asarray(images[: int(len(images) * 0.8)]),
    np.asarray(targets[: int(len(targets) * 0.8)]),
)
(x_test), (y_test) = (
    np.asarray(images[int(len(images) * 0.8) :]),
    np.asarray(targets[int(len(targets) * 0.8) :]),
)
# Out:
# /tmp/ipykernel_987583/8725736.py:69: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.asarray(images[int(len(images) * 0.8) :]),

# %%
(x_train.shape), (y_train.shape)
# Out:
# ((640, 224, 224, 3), (640, 4))

# %%
(x_test.shape), (y_test.shape)
# Out:
# ((160,), (160, 4))

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    #     Override function to avoid error while saving model
    def get_config(self):
        config = super().get_config().copy()
        config.update(
            {
                "input_shape": input_shape,
                "patch_size": patch_size,
                "num_patches": num_patches,
                "projection_dim": projection_dim,
                "num_heads": num_heads,
                "transformer_units": transformer_units,
                "transformer_layers": transformer_layers,
                "mlp_head_units": mlp_head_units,
            }
        )
        return config

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        # return patches
        return tf.reshape(patches, [batch_size, -1, patches.shape[-1]])

# %%
patch_size = 32  # Size of the patches to be extracted from the input images

plt.figure(figsize=(4, 4))
plt.imshow(x_train[0].astype("uint8"))
plt.axis("off")

patches = Patches(patch_size)(tf.convert_to_tensor([x_train[0]]))
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"{patches.shape[1]} patches per image \n{patches.shape[-1]} elements per patch")


n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# 2023-09-02 11:53:23.812083: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: 无法打开共享对象文件: 没有那个文件或目录; LD_LIBRARY_PATH: /home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-09-02 11:53:23.812137: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Image size: 224 X 224
# Patch size: 32 X 32
# 49 patches per image
# 3072 elements per patch

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    # Override function to avoid error while saving model
    def get_config(self):
        config = super().get_config().copy()
        config.update(
            {
                "input_shape": input_shape,
                "patch_size": patch_size,
                "num_patches": num_patches,
                "projection_dim": projection_dim,
                "num_heads": num_heads,
                "transformer_units": transformer_units,
                "transformer_layers": transformer_layers,
                "mlp_head_units": mlp_head_units,
            }
        )
        return config

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_object_detector(
    input_shape,
    patch_size,
    num_patches,
    projection_dim,
    num_heads,
    transformer_units,
    transformer_layers,
    mlp_head_units,
):
    inputs = layers.Input(shape=input_shape)
    # Create patches
    patches = Patches(patch_size)(inputs)
    # Encode patches
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.3)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.3)

    bounding_box = layers.Dense(4)(
        features
    )  # Final four neurons that output bounding box

    # return Keras model.
    return keras.Model(inputs=inputs, outputs=bounding_box)

# %%
def run_experiment(model, learning_rate, weight_decay, batch_size, num_epochs):

    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    # Compile model.
    model.compile(optimizer=optimizer, loss=keras.losses.MeanSquaredError())

    checkpoint_filepath = "logs/"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_loss",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[
            checkpoint_callback,
            keras.callbacks.EarlyStopping(monitor="val_loss", patience=10),
        ],
    )

    return history


input_shape = (image_size, image_size, 3)  # input image shape
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 32
num_epochs = 5
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
# Size of the transformer layers
transformer_units = [
    projection_dim * 2,
    projection_dim,
]
transformer_layers = 4
mlp_head_units = [2048, 1024, 512, 64, 32]  # Size of the dense layers


history = []
num_patches = (image_size // patch_size) ** 2

vit_object_detector = create_vit_object_detector(
    input_shape,
    patch_size,
    num_patches,
    projection_dim,
    num_heads,
    transformer_units,
    transformer_layers,
    mlp_head_units,
)

# Train model
history = run_experiment(
    vit_object_detector, learning_rate, weight_decay, batch_size, num_epochs
)
# Out:
# Epoch 1/5
# 18/18 [==============================] - 8s 232ms/step - loss: 0.7801 - val_loss: 0.3504
# Epoch 2/5
# 18/18 [==============================] - 3s 184ms/step - loss: 0.3607 - val_loss: 0.3045
# Epoch 3/5
# 18/18 [==============================] - 3s 182ms/step - loss: 0.2893 - val_loss: 0.2622
# Epoch 4/5
# 18/18 [==============================] - 3s 185ms/step - loss: 0.2374 - val_loss: 0.2283
# Epoch 5/5
# 18/18 [==============================] - 4s 199ms/step - loss: 0.2008 - val_loss: 0.1593

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
# Plot the change of loss during training
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Val'], loc='upper right')
plt.show()

# %%
import matplotlib.patches as patches

# Saves the model in current path
vit_object_detector.save("vit_object_detector.h5", save_format="h5")

# To calculate IoU (intersection over union, given two bounding boxes)
def bounding_box_intersection_over_union(box_predicted, box_truth):
    # get (x, y) coordinates of intersection of bounding boxes
    top_x_intersect = max(box_predicted[0], box_truth[0])
    top_y_intersect = max(box_predicted[1], box_truth[1])
    bottom_x_intersect = min(box_predicted[2], box_truth[2])
    bottom_y_intersect = min(box_predicted[3], box_truth[3])

    # calculate area of the intersection bb (bounding box)
    intersection_area = max(0, bottom_x_intersect - top_x_intersect + 1) * max(
        0, bottom_y_intersect - top_y_intersect + 1
    )

    # calculate area of the prediction bb and ground-truth bb
    box_predicted_area = (box_predicted[2] - box_predicted[0] + 1) * (
        box_predicted[3] - box_predicted[1] + 1
    )
    box_truth_area = (box_truth[2] - box_truth[0] + 1) * (
        box_truth[3] - box_truth[1] + 1
    )

    # calculate intersection over union by taking intersection
    # area and dividing it by the sum of predicted bb and ground truth
    # bb areas subtracted by  the interesection area

    # return ioU
    return intersection_area / float(
        box_predicted_area + box_truth_area - intersection_area
    )


i, mean_iou = 0, 0

# Compare results for 10 images in the test set
for input_image in x_test[:10]:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 15))
    im = input_image

    # Display the image
    ax1.imshow(im.astype("uint8"))
    ax2.imshow(im.astype("uint8"))

    input_image = cv2.resize(
        input_image, (image_size, image_size), interpolation=cv2.INTER_AREA
    )
    input_image = np.expand_dims(input_image, axis=0)
    preds = vit_object_detector.predict(input_image)[0]

    (h, w) = (im).shape[0:2]

    top_left_x, top_left_y = int(preds[0] * w), int(preds[1] * h)

    bottom_right_x, bottom_right_y = int(preds[2] * w), int(preds[3] * h)

    box_predicted = [top_left_x, top_left_y, bottom_right_x, bottom_right_y]
    # Create the bounding box
    rect = patches.Rectangle(
        (top_left_x, top_left_y),
        bottom_right_x - top_left_x,
        bottom_right_y - top_left_y,
        facecolor="none",
        edgecolor="red",
        linewidth=1,
    )
    # Add the bounding box to the image
    ax1.add_patch(rect)
    ax1.set_xlabel(
        "Predicted: "
        + str(top_left_x)
        + ", "
        + str(top_left_y)
        + ", "
        + str(bottom_right_x)
        + ", "
        + str(bottom_right_y)
    )

    top_left_x, top_left_y = int(y_test[i][0] * w), int(y_test[i][1] * h)

    bottom_right_x, bottom_right_y = int(y_test[i][2] * w), int(y_test[i][3] * h)

    box_truth = top_left_x, top_left_y, bottom_right_x, bottom_right_y

    mean_iou += bounding_box_intersection_over_union(box_predicted, box_truth)
    # Create the bounding box
    rect = patches.Rectangle(
        (top_left_x, top_left_y),
        bottom_right_x - top_left_x,
        bottom_right_y - top_left_y,
        facecolor="none",
        edgecolor="red",
        linewidth=1,
    )
    # Add the bounding box to the image
    ax2.add_patch(rect)
    ax2.set_xlabel(
        "Target: "
        + str(top_left_x)
        + ", "
        + str(top_left_y)
        + ", "
        + str(bottom_right_x)
        + ", "
        + str(bottom_right_y)
        + "\n"
        + "IoU"
        + str(bounding_box_intersection_over_union(box_predicted, box_truth))
    )
    i = i + 1

print("mean_iou: " + str(mean_iou / len(x_test[:10])))
plt.show()
# Out:
# 1/1 [==============================] - 1s 915ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# mean_iou: 0.028891551612908063

# %%
x_train.shape
# Out:
# (640, 224, 224, 3)

# %%
y_train.shape
# Out:
# (640, 4)

# %%
x_test.shape, y_test.shape
# Out:
# ((160,), (160, 4))

# %%
"""
from tensorflow.keras.utils import Sequence

class DataLoader(Sequence):
    def __init__(self, x_set, y_set, batch_size):
        self.x_set = x_set
        self.y_set = y_set
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.x_set) / float(self.batch_size)))
    
    def dataset_len(self):
        return self.x_set.shape[0]
    
    def  __getitem__(self, idx):
        batch_x = self.x_set[idx * self.batch_size:(idx + 1) * self.batch_size] 
        batch_y = self.y_set[idx * self.batch_size:(idx + 1) * self.batch_size]

        return np.array(batch_x), np.array(batch_y)
"""
# Out:
# '\nfrom tensorflow.keras.utils import Sequence\n\nclass DataLoader(Sequence):\n    def __init__(self, x_set, y_set, batch_size):\n        self.x_set = x_set\n        self.y_set = y_set\n        self.batch_size = batch_size\n\n    def __len__(self):\n        return int(np.ceil(len(self.x_set) / float(self.batch_size)))\n    \n    def dataset_len(self):\n        return self.x_set.shape[0]\n    \n    def  __getitem__(self, idx):\n        batch_x = self.x_set[idx * self.batch_size:(idx + 1) * self.batch_size] \n        batch_y = self.y_set[idx * self.batch_size:(idx + 1) * self.batch_size]\n\n        return np.array(batch_x), np.array(batch_y)\n'

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.1, random_state=42)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
eval_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %%
BATCH_SIZE = 64
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
eval_dataset = eval_dataset.batch(BATCH_SIZE)

# %%
model = create_vit_object_detector(
    input_shape,
    patch_size,
    num_patches,
    projection_dim,
    num_heads,
    transformer_units,
    transformer_layers,
    mlp_head_units,
)

optimizer = tfa.optimizers.AdamW(
    learning_rate=learning_rate, weight_decay=weight_decay
)

# Compile model.
model.compile(optimizer=optimizer, loss=keras.losses.MeanSquaredError())

checkpoint_filepath = "logs/"
checkpoint_callback = keras.callbacks.ModelCheckpoint(
    checkpoint_filepath,
    monitor="val_loss",
    save_best_only=True,
    save_weights_only=True,
)

# %%
history = model.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=eval_dataset,
    callbacks=[
        checkpoint_callback,
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=10),
    ],
)
# Out:
# Epoch 1/5
# 9/9 [==============================] - 9s 413ms/step - loss: 0.7529 - val_loss: 0.2060
# Epoch 2/5
# 9/9 [==============================] - 2s 204ms/step - loss: 0.3983 - val_loss: 0.3272
# Epoch 3/5
# 9/9 [==============================] - 2s 203ms/step - loss: 0.3361 - val_loss: 0.3050
# Epoch 4/5
# 9/9 [==============================] - 2s 200ms/step - loss: 0.2991 - val_loss: 0.2828
# Epoch 5/5
# 9/9 [==============================] - 2s 202ms/step - loss: 0.2756 - val_loss: 0.2611

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
# Plot the change of loss during training
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Val'], loc='upper right')
plt.show()

# %% [markdown]
# ## FL mode

# %% [markdown]
# ### Data split

# %%
# Path to images and annotations
path_images = "./101_ObjectCategories/airplanes/"
path_annot = "./Annotations/Airplanes_Side_2/"

# list of paths to images and annotations
image_paths = [
    f for f in os.listdir(path_images) if os.path.isfile(os.path.join(path_images, f))
]
annot_paths = [
    f for f in os.listdir(path_annot) if os.path.isfile(os.path.join(path_annot, f))
]

image_paths.sort()
annot_paths.sort()

# %%
image_paths
# Out:
# ['image_0001.jpg',
#  'image_0002.jpg',
#  'image_0003.jpg',
#  'image_0004.jpg',
#  'image_0005.jpg',
#  'image_0006.jpg',
#  'image_0007.jpg',
#  'image_0008.jpg',
#  'image_0009.jpg',
#  'image_0010.jpg',
#  'image_0011.jpg',
#  'image_0012.jpg',
#  'image_0013.jpg',
#  'image_0014.jpg',
#  'image_0015.jpg',
#  'image_0016.jpg',
#  'image_0017.jpg',
#  'image_0018.jpg',
#  'image_0019.jpg',
#  'image_0020.jpg',
#  'image_0021.jpg',
#  'image_0022.jpg',
#  'image_0023.jpg',
#  'image_0024.jpg',
#  'image_0025.jpg',
#  'image_0026.jpg',
#  'image_0027.jpg',
#  'image_0028.jpg',
#  'image_0029.jpg',
#  'image_0030.jpg',
#  'image_0031.jpg',
#  'image_0032.jpg',
#  'image_0033.jpg',
#  'image_0034.jpg',
#  'image_0035.jpg',
#  'image_0036.jpg',
#  'image_0037.jpg',
#  'image_0038.jpg',
#  'image_0039.jpg',
#  'image_0040.jpg',
#  'image_0041.jpg',
#  'image_0042.jpg',
#  'image_0043.jpg',
#  'image_0044.jpg',
#  'image_0045.jpg',
#  'image_0046.jpg',
#  'image_0047.jpg',
#  'image_0048.jpg',
#  'image_0049.jpg',
#  'image_0050.jpg',
#  'image_0051.jpg',
#  'image_0052.jpg',
#  'image_0053.jpg',
#  'image_0054.jpg',
#  'image_0055.jpg',
#  'image_0056.jpg',
#  'image_0057.jpg',
#  'image_0058.jpg',
#  'image_0059.jpg',
#  'image_0060.jpg',
#  'image_0061.jpg',
#  'image_0062.jpg',
#  'image_0063.jpg',
#  'image_0064.jpg',
#  'image_0065.jpg',
#  'image_0066.jpg',
#  'image_0067.jpg',
#  'image_0068.jpg',
#  'image_0069.jpg',
#  'image_0070.jpg',
#  'image_0071.jpg',
#  'image_0072.jpg',
#  'image_0073.jpg',
#  'image_0074.jpg',
#  'image_0075.jpg',
#  'image_0076.jpg',
#  'image_0077.jpg',
#  'image_0078.jpg',
#  'image_0079.jpg',
#  'image_0080.jpg',
#  'image_0081.jpg',
#  'image_0082.jpg',
#  'image_0083.jpg',
#  'image_0084.jpg',
#  'image_0085.jpg',
#  'image_0086.jpg',
#  'image_0087.jpg',
#  'image_0088.jpg',
#  'image_0089.jpg',
#  'image_0090.jpg',
#  'image_0091.jpg',
#  'image_0092.jpg',
#  'image_0093.jpg',
#  'image_0094.jpg',
#  'image_0095.jpg',
#  'image_0096.jpg',
#  'image_0097.jpg',
#  'image_0098.jpg',
#  'image_0099.jpg',
#  'image_0100.jpg',
#  'image_0101.jpg',
#  'image_0102.jpg',
#  'image_0103.jpg',
#  'image_0104.jpg',
#  'image_0105.jpg',
#  'image_0106.jpg',
#  'image_0107.jpg',
#  'image_0108.jpg',
#  'image_0109.jpg',
#  'image_0110.jpg',
#  'image_0111.jpg',
#  'image_0112.jpg',
#  'image_0113.jpg',
#  'image_0114.jpg',
#  'image_0115.jpg',
#  'image_0116.jpg',
#  'image_0117.jpg',
#  'image_0118.jpg',
#  'image_0119.jpg',
#  'image_0120.jpg',
#  'image_0121.jpg',
#  'image_0122.jpg',
#  'image_0123.jpg',
#  'image_0124.jpg',
#  'image_0125.jpg',
#  'image_0126.jpg',
#  'image_0127.jpg',
#  'image_0128.jpg',
#  'image_0129.jpg',
#  'image_0130.jpg',
#  'image_0131.jpg',
#  'image_0132.jpg',
#  'image_0133.jpg',
#  'image_0134.jpg',
#  'image_0135.jpg',
#  'image_0136.jpg',
#  'image_0137.jpg',
#  'image_0138.jpg',
#  'image_0139.jpg',
#  'image_0140.jpg',
#  'image_0141.jpg',
#  'image_0142.jpg',
#  'image_0143.jpg',
#  'image_0144.jpg',
#  'image_0145.jpg',
#  'image_0146.jpg',
#  'image_0147.jpg',
#  'image_0148.jpg',
#  'image_0149.jpg',
#  'image_0150.jpg',
#  'image_0151.jpg',
#  'image_0152.jpg',
#  'image_0153.jpg',
#  'image_0154.jpg',
#  'image_0155.jpg',
#  'image_0156.jpg',
#  'image_0157.jpg',
#  'image_0158.jpg',
#  'image_0159.jpg',
#  'image_0160.jpg',
#  'image_0161.jpg',
#  'image_0162.jpg',
#  'image_0163.jpg',
#  'image_0164.jpg',
#  'image_0165.jpg',
#  'image_0166.jpg',
#  'image_0167.jpg',
#  'image_0168.jpg',
#  'image_0169.jpg',
#  'image_0170.jpg',
#  'image_0171.jpg',
#  'image_0172.jpg',
#  'image_0173.jpg',
#  'image_0174.jpg',
#  'image_0175.jpg',
#  'image_0176.jpg',
#  'image_0177.jpg',
#  'image_0178.jpg',
#  'image_0179.jpg',
#  'image_0180.jpg',
#  'image_0181.jpg',
#  'image_0182.jpg',
#  'image_0183.jpg',
#  'image_0184.jpg',
#  'image_0185.jpg',
#  'image_0186.jpg',
#  'image_0187.jpg',
#  'image_0188.jpg',
#  'image_0189.jpg',
#  'image_0190.jpg',
#  'image_0191.jpg',
#  'image_0192.jpg',
#  'image_0193.jpg',
#  'image_0194.jpg',
#  'image_0195.jpg',
#  'image_0196.jpg',
#  'image_0197.jpg',
#  'image_0198.jpg',
#  'image_0199.jpg',
#  'image_0200.jpg',
#  'image_0201.jpg',
#  'image_0202.jpg',
#  'image_0203.jpg',
#  'image_0204.jpg',
#  'image_0205.jpg',
#  'image_0206.jpg',
#  'image_0207.jpg',
#  'image_0208.jpg',
#  'image_0209.jpg',
#  'image_0210.jpg',
#  'image_0211.jpg',
#  'image_0212.jpg',
#  'image_0213.jpg',
#  'image_0214.jpg',
#  'image_0215.jpg',
#  'image_0216.jpg',
#  'image_0217.jpg',
#  'image_0218.jpg',
#  'image_0219.jpg',
#  'image_0220.jpg',
#  'image_0221.jpg',
#  'image_0222.jpg',
#  'image_0223.jpg',
#  'image_0224.jpg',
#  'image_0225.jpg',
#  'image_0226.jpg',
#  'image_0227.jpg',
#  'image_0228.jpg',
#  'image_0229.jpg',
#  'image_0230.jpg',
#  'image_0231.jpg',
#  'image_0232.jpg',
#  'image_0233.jpg',
#  'image_0234.jpg',
#  'image_0235.jpg',
#  'image_0236.jpg',
#  'image_0237.jpg',
#  'image_0238.jpg',
#  'image_0239.jpg',
#  'image_0240.jpg',
#  'image_0241.jpg',
#  'image_0242.jpg',
#  'image_0243.jpg',
#  'image_0244.jpg',
#  'image_0245.jpg',
#  'image_0246.jpg',
#  'image_0247.jpg',
#  'image_0248.jpg',
#  'image_0249.jpg',
#  'image_0250.jpg',
#  'image_0251.jpg',
#  'image_0252.jpg',
#  'image_0253.jpg',
#  'image_0254.jpg',
#  'image_0255.jpg',
#  'image_0256.jpg',
#  'image_0257.jpg',
#  'image_0258.jpg',
#  'image_0259.jpg',
#  'image_0260.jpg',
#  'image_0261.jpg',
#  'image_0262.jpg',
#  'image_0263.jpg',
#  'image_0264.jpg',
#  'image_0265.jpg',
#  'image_0266.jpg',
#  'image_0267.jpg',
#  'image_0268.jpg',
#  'image_0269.jpg',
#  'image_0270.jpg',
#  'image_0271.jpg',
#  'image_0272.jpg',
#  'image_0273.jpg',
#  'image_0274.jpg',
#  'image_0275.jpg',
#  'image_0276.jpg',
#  'image_0277.jpg',
#  'image_0278.jpg',
#  'image_0279.jpg',
#  'image_0280.jpg',
#  'image_0281.jpg',
#  'image_0282.jpg',
#  'image_0283.jpg',
#  'image_0284.jpg',
#  'image_0285.jpg',
#  'image_0286.jpg',
#  'image_0287.jpg',
#  'image_0288.jpg',
#  'image_0289.jpg',
#  'image_0290.jpg',
#  'image_0291.jpg',
#  'image_0292.jpg',
#  'image_0293.jpg',
#  'image_0294.jpg',
#  'image_0295.jpg',
#  'image_0296.jpg',
#  'image_0297.jpg',
#  'image_0298.jpg',
#  'image_0299.jpg',
#  'image_0300.jpg',
#  'image_0301.jpg',
#  'image_0302.jpg',
#  'image_0303.jpg',
#  'image_0304.jpg',
#  'image_0305.jpg',
#  'image_0306.jpg',
#  'image_0307.jpg',
#  'image_0308.jpg',
#  'image_0309.jpg',
#  'image_0310.jpg',
#  'image_0311.jpg',
#  'image_0312.jpg',
#  'image_0313.jpg',
#  'image_0314.jpg',
#  'image_0315.jpg',
#  'image_0316.jpg',
#  'image_0317.jpg',
#  'image_0318.jpg',
#  'image_0319.jpg',
#  'image_0320.jpg',
#  'image_0321.jpg',
#  'image_0322.jpg',
#  'image_0323.jpg',
#  'image_0324.jpg',
#  'image_0325.jpg',
#  'image_0326.jpg',
#  'image_0327.jpg',
#  'image_0328.jpg',
#  'image_0329.jpg',
#  'image_0330.jpg',
#  'image_0331.jpg',
#  'image_0332.jpg',
#  'image_0333.jpg',
#  'image_0334.jpg',
#  'image_0335.jpg',
#  'image_0336.jpg',
#  'image_0337.jpg',
#  'image_0338.jpg',
#  'image_0339.jpg',
#  'image_0340.jpg',
#  'image_0341.jpg',
#  'image_0342.jpg',
#  'image_0343.jpg',
#  'image_0344.jpg',
#  'image_0345.jpg',
#  'image_0346.jpg',
#  'image_0347.jpg',
#  'image_0348.jpg',
#  'image_0349.jpg',
#  'image_0350.jpg',
#  'image_0351.jpg',
#  'image_0352.jpg',
#  'image_0353.jpg',
#  'image_0354.jpg',
#  'image_0355.jpg',
#  'image_0356.jpg',
#  'image_0357.jpg',
#  'image_0358.jpg',
#  'image_0359.jpg',
#  'image_0360.jpg',
#  'image_0361.jpg',
#  'image_0362.jpg',
#  'image_0363.jpg',
#  'image_0364.jpg',
#  'image_0365.jpg',
#  'image_0366.jpg',
#  'image_0367.jpg',
#  'image_0368.jpg',
#  'image_0369.jpg',
#  'image_0370.jpg',
#  'image_0371.jpg',
#  'image_0372.jpg',
#  'image_0373.jpg',
#  'image_0374.jpg',
#  'image_0375.jpg',
#  'image_0376.jpg',
#  'image_0377.jpg',
#  'image_0378.jpg',
#  'image_0379.jpg',
#  'image_0380.jpg',
#  'image_0381.jpg',
#  'image_0382.jpg',
#  'image_0383.jpg',
#  'image_0384.jpg',
#  'image_0385.jpg',
#  'image_0386.jpg',
#  'image_0387.jpg',
#  'image_0388.jpg',
#  'image_0389.jpg',
#  'image_0390.jpg',
#  'image_0391.jpg',
#  'image_0392.jpg',
#  'image_0393.jpg',
#  'image_0394.jpg',
#  'image_0395.jpg',
#  'image_0396.jpg',
#  'image_0397.jpg',
#  'image_0398.jpg',
#  'image_0399.jpg',
#  'image_0400.jpg',
#  'image_0401.jpg',
#  'image_0402.jpg',
#  'image_0403.jpg',
#  'image_0404.jpg',
#  'image_0405.jpg',
#  'image_0406.jpg',
#  'image_0407.jpg',
#  'image_0408.jpg',
#  'image_0409.jpg',
#  'image_0410.jpg',
#  'image_0411.jpg',
#  'image_0412.jpg',
#  'image_0413.jpg',
#  'image_0414.jpg',
#  'image_0415.jpg',
#  'image_0416.jpg',
#  'image_0417.jpg',
#  'image_0418.jpg',
#  'image_0419.jpg',
#  'image_0420.jpg',
#  'image_0421.jpg',
#  'image_0422.jpg',
#  'image_0423.jpg',
#  'image_0424.jpg',
#  'image_0425.jpg',
#  'image_0426.jpg',
#  'image_0427.jpg',
#  'image_0428.jpg',
#  'image_0429.jpg',
#  'image_0430.jpg',
#  'image_0431.jpg',
#  'image_0432.jpg',
#  'image_0433.jpg',
#  'image_0434.jpg',
#  'image_0435.jpg',
#  'image_0436.jpg',
#  'image_0437.jpg',
#  'image_0438.jpg',
#  'image_0439.jpg',
#  'image_0440.jpg',
#  'image_0441.jpg',
#  'image_0442.jpg',
#  'image_0443.jpg',
#  'image_0444.jpg',
#  'image_0445.jpg',
#  'image_0446.jpg',
#  'image_0447.jpg',
#  'image_0448.jpg',
#  'image_0449.jpg',
#  'image_0450.jpg',
#  'image_0451.jpg',
#  'image_0452.jpg',
#  'image_0453.jpg',
#  'image_0454.jpg',
#  'image_0455.jpg',
#  'image_0456.jpg',
#  'image_0457.jpg',
#  'image_0458.jpg',
#  'image_0459.jpg',
#  'image_0460.jpg',
#  'image_0461.jpg',
#  'image_0462.jpg',
#  'image_0463.jpg',
#  'image_0464.jpg',
#  'image_0465.jpg',
#  'image_0466.jpg',
#  'image_0467.jpg',
#  'image_0468.jpg',
#  'image_0469.jpg',
#  'image_0470.jpg',
#  'image_0471.jpg',
#  'image_0472.jpg',
#  'image_0473.jpg',
#  'image_0474.jpg',
#  'image_0475.jpg',
#  'image_0476.jpg',
#  'image_0477.jpg',
#  'image_0478.jpg',
#  'image_0479.jpg',
#  'image_0480.jpg',
#  'image_0481.jpg',
#  'image_0482.jpg',
#  'image_0483.jpg',
#  'image_0484.jpg',
#  'image_0485.jpg',
#  'image_0486.jpg',
#  'image_0487.jpg',
#  'image_0488.jpg',
#  'image_0489.jpg',
#  'image_0490.jpg',
#  'image_0491.jpg',
#  'image_0492.jpg',
#  'image_0493.jpg',
#  'image_0494.jpg',
#  'image_0495.jpg',
#  'image_0496.jpg',
#  'image_0497.jpg',
#  'image_0498.jpg',
#  'image_0499.jpg',
#  'image_0500.jpg',
#  'image_0501.jpg',
#  'image_0502.jpg',
#  'image_0503.jpg',
#  'image_0504.jpg',
#  'image_0505.jpg',
#  'image_0506.jpg',
#  'image_0507.jpg',
#  'image_0508.jpg',
#  'image_0509.jpg',
#  'image_0510.jpg',
#  'image_0511.jpg',
#  'image_0512.jpg',
#  'image_0513.jpg',
#  'image_0514.jpg',
#  'image_0515.jpg',
#  'image_0516.jpg',
#  'image_0517.jpg',
#  'image_0518.jpg',
#  'image_0519.jpg',
#  'image_0520.jpg',
#  'image_0521.jpg',
#  'image_0522.jpg',
#  'image_0523.jpg',
#  'image_0524.jpg',
#  'image_0525.jpg',
#  'image_0526.jpg',
#  'image_0527.jpg',
#  'image_0528.jpg',
#  'image_0529.jpg',
#  'image_0530.jpg',
#  'image_0531.jpg',
#  'image_0532.jpg',
#  'image_0533.jpg',
#  'image_0534.jpg',
#  'image_0535.jpg',
#  'image_0536.jpg',
#  'image_0537.jpg',
#  'image_0538.jpg',
#  'image_0539.jpg',
#  'image_0540.jpg',
#  'image_0541.jpg',
#  'image_0542.jpg',
#  'image_0543.jpg',
#  'image_0544.jpg',
#  'image_0545.jpg',
#  'image_0546.jpg',
#  'image_0547.jpg',
#  'image_0548.jpg',
#  'image_0549.jpg',
#  'image_0550.jpg',
#  'image_0551.jpg',
#  'image_0552.jpg',
#  'image_0553.jpg',
#  'image_0554.jpg',
#  'image_0555.jpg',
#  'image_0556.jpg',
#  'image_0557.jpg',
#  'image_0558.jpg',
#  'image_0559.jpg',
#  'image_0560.jpg',
#  'image_0561.jpg',
#  'image_0562.jpg',
#  'image_0563.jpg',
#  'image_0564.jpg',
#  'image_0565.jpg',
#  'image_0566.jpg',
#  'image_0567.jpg',
#  'image_0568.jpg',
#  'image_0569.jpg',
#  'image_0570.jpg',
#  'image_0571.jpg',
#  'image_0572.jpg',
#  'image_0573.jpg',
#  'image_0574.jpg',
#  'image_0575.jpg',
#  'image_0576.jpg',
#  'image_0577.jpg',
#  'image_0578.jpg',
#  'image_0579.jpg',
#  'image_0580.jpg',
#  'image_0581.jpg',
#  'image_0582.jpg',
#  'image_0583.jpg',
#  'image_0584.jpg',
#  'image_0585.jpg',
#  'image_0586.jpg',
#  'image_0587.jpg',
#  'image_0588.jpg',
#  'image_0589.jpg',
#  'image_0590.jpg',
#  'image_0591.jpg',
#  'image_0592.jpg',
#  'image_0593.jpg',
#  'image_0594.jpg',
#  'image_0595.jpg',
#  'image_0596.jpg',
#  'image_0597.jpg',
#  'image_0598.jpg',
#  'image_0599.jpg',
#  'image_0600.jpg',
#  'image_0601.jpg',
#  'image_0602.jpg',
#  'image_0603.jpg',
#  'image_0604.jpg',
#  'image_0605.jpg',
#  'image_0606.jpg',
#  'image_0607.jpg',
#  'image_0608.jpg',
#  'image_0609.jpg',
#  'image_0610.jpg',
#  'image_0611.jpg',
#  'image_0612.jpg',
#  'image_0613.jpg',
#  'image_0614.jpg',
#  'image_0615.jpg',
#  'image_0616.jpg',
#  'image_0617.jpg',
#  'image_0618.jpg',
#  'image_0619.jpg',
#  'image_0620.jpg',
#  'image_0621.jpg',
#  'image_0622.jpg',
#  'image_0623.jpg',
#  'image_0624.jpg',
#  'image_0625.jpg',
#  'image_0626.jpg',
#  'image_0627.jpg',
#  'image_0628.jpg',
#  'image_0629.jpg',
#  'image_0630.jpg',
#  'image_0631.jpg',
#  'image_0632.jpg',
#  'image_0633.jpg',
#  'image_0634.jpg',
#  'image_0635.jpg',
#  'image_0636.jpg',
#  'image_0637.jpg',
#  'image_0638.jpg',
#  'image_0639.jpg',
#  'image_0640.jpg',
#  'image_0641.jpg',
#  'image_0642.jpg',
#  'image_0643.jpg',
#  'image_0644.jpg',
#  'image_0645.jpg',
#  'image_0646.jpg',
#  'image_0647.jpg',
#  'image_0648.jpg',
#  'image_0649.jpg',
#  'image_0650.jpg',
#  'image_0651.jpg',
#  'image_0652.jpg',
#  'image_0653.jpg',
#  'image_0654.jpg',
#  'image_0655.jpg',
#  'image_0656.jpg',
#  'image_0657.jpg',
#  'image_0658.jpg',
#  'image_0659.jpg',
#  'image_0660.jpg',
#  'image_0661.jpg',
#  'image_0662.jpg',
#  'image_0663.jpg',
#  'image_0664.jpg',
#  'image_0665.jpg',
#  'image_0666.jpg',
#  'image_0667.jpg',
#  'image_0668.jpg',
#  'image_0669.jpg',
#  'image_0670.jpg',
#  'image_0671.jpg',
#  'image_0672.jpg',
#  'image_0673.jpg',
#  'image_0674.jpg',
#  'image_0675.jpg',
#  'image_0676.jpg',
#  'image_0677.jpg',
#  'image_0678.jpg',
#  'image_0679.jpg',
#  'image_0680.jpg',
#  'image_0681.jpg',
#  'image_0682.jpg',
#  'image_0683.jpg',
#  'image_0684.jpg',
#  'image_0685.jpg',
#  'image_0686.jpg',
#  'image_0687.jpg',
#  'image_0688.jpg',
#  'image_0689.jpg',
#  'image_0690.jpg',
#  'image_0691.jpg',
#  'image_0692.jpg',
#  'image_0693.jpg',
#  'image_0694.jpg',
#  'image_0695.jpg',
#  'image_0696.jpg',
#  'image_0697.jpg',
#  'image_0698.jpg',
#  'image_0699.jpg',
#  'image_0700.jpg',
#  'image_0701.jpg',
#  'image_0702.jpg',
#  'image_0703.jpg',
#  'image_0704.jpg',
#  'image_0705.jpg',
#  'image_0706.jpg',
#  'image_0707.jpg',
#  'image_0708.jpg',
#  'image_0709.jpg',
#  'image_0710.jpg',
#  'image_0711.jpg',
#  'image_0712.jpg',
#  'image_0713.jpg',
#  'image_0714.jpg',
#  'image_0715.jpg',
#  'image_0716.jpg',
#  'image_0717.jpg',
#  'image_0718.jpg',
#  'image_0719.jpg',
#  'image_0720.jpg',
#  'image_0721.jpg',
#  'image_0722.jpg',
#  'image_0723.jpg',
#  'image_0724.jpg',
#  'image_0725.jpg',
#  'image_0726.jpg',
#  'image_0727.jpg',
#  'image_0728.jpg',
#  'image_0729.jpg',
#  'image_0730.jpg',
#  'image_0731.jpg',
#  'image_0732.jpg',
#  'image_0733.jpg',
#  'image_0734.jpg',
#  'image_0735.jpg',
#  'image_0736.jpg',
#  'image_0737.jpg',
#  'image_0738.jpg',
#  'image_0739.jpg',
#  'image_0740.jpg',
#  'image_0741.jpg',
#  'image_0742.jpg',
#  'image_0743.jpg',
#  'image_0744.jpg',
#  'image_0745.jpg',
#  'image_0746.jpg',
#  'image_0747.jpg',
#  'image_0748.jpg',
#  'image_0749.jpg',
#  'image_0750.jpg',
#  'image_0751.jpg',
#  'image_0752.jpg',
#  'image_0753.jpg',
#  'image_0754.jpg',
#  'image_0755.jpg',
#  'image_0756.jpg',
#  'image_0757.jpg',
#  'image_0758.jpg',
#  'image_0759.jpg',
#  'image_0760.jpg',
#  'image_0761.jpg',
#  'image_0762.jpg',
#  'image_0763.jpg',
#  'image_0764.jpg',
#  'image_0765.jpg',
#  'image_0766.jpg',
#  'image_0767.jpg',
#  'image_0768.jpg',
#  'image_0769.jpg',
#  'image_0770.jpg',
#  'image_0771.jpg',
#  'image_0772.jpg',
#  'image_0773.jpg',
#  'image_0774.jpg',
#  'image_0775.jpg',
#  'image_0776.jpg',
#  'image_0777.jpg',
#  'image_0778.jpg',
#  'image_0779.jpg',
#  'image_0780.jpg',
#  'image_0781.jpg',
#  'image_0782.jpg',
#  'image_0783.jpg',
#  'image_0784.jpg',
#  'image_0785.jpg',
#  'image_0786.jpg',
#  'image_0787.jpg',
#  'image_0788.jpg',
#  'image_0789.jpg',
#  'image_0790.jpg',
#  'image_0791.jpg',
#  'image_0792.jpg',
#  'image_0793.jpg',
#  'image_0794.jpg',
#  'image_0795.jpg',
#  'image_0796.jpg',
#  'image_0797.jpg',
#  'image_0798.jpg',
#  'image_0799.jpg',
#  'image_0800.jpg']

# %%
annot_paths
# Out:
# ['annotation_0001.mat',
#  'annotation_0002.mat',
#  'annotation_0003.mat',
#  'annotation_0004.mat',
#  'annotation_0005.mat',
#  'annotation_0006.mat',
#  'annotation_0007.mat',
#  'annotation_0008.mat',
#  'annotation_0009.mat',
#  'annotation_0010.mat',
#  'annotation_0011.mat',
#  'annotation_0012.mat',
#  'annotation_0013.mat',
#  'annotation_0014.mat',
#  'annotation_0015.mat',
#  'annotation_0016.mat',
#  'annotation_0017.mat',
#  'annotation_0018.mat',
#  'annotation_0019.mat',
#  'annotation_0020.mat',
#  'annotation_0021.mat',
#  'annotation_0022.mat',
#  'annotation_0023.mat',
#  'annotation_0024.mat',
#  'annotation_0025.mat',
#  'annotation_0026.mat',
#  'annotation_0027.mat',
#  'annotation_0028.mat',
#  'annotation_0029.mat',
#  'annotation_0030.mat',
#  'annotation_0031.mat',
#  'annotation_0032.mat',
#  'annotation_0033.mat',
#  'annotation_0034.mat',
#  'annotation_0035.mat',
#  'annotation_0036.mat',
#  'annotation_0037.mat',
#  'annotation_0038.mat',
#  'annotation_0039.mat',
#  'annotation_0040.mat',
#  'annotation_0041.mat',
#  'annotation_0042.mat',
#  'annotation_0043.mat',
#  'annotation_0044.mat',
#  'annotation_0045.mat',
#  'annotation_0046.mat',
#  'annotation_0047.mat',
#  'annotation_0048.mat',
#  'annotation_0049.mat',
#  'annotation_0050.mat',
#  'annotation_0051.mat',
#  'annotation_0052.mat',
#  'annotation_0053.mat',
#  'annotation_0054.mat',
#  'annotation_0055.mat',
#  'annotation_0056.mat',
#  'annotation_0057.mat',
#  'annotation_0058.mat',
#  'annotation_0059.mat',
#  'annotation_0060.mat',
#  'annotation_0061.mat',
#  'annotation_0062.mat',
#  'annotation_0063.mat',
#  'annotation_0064.mat',
#  'annotation_0065.mat',
#  'annotation_0066.mat',
#  'annotation_0067.mat',
#  'annotation_0068.mat',
#  'annotation_0069.mat',
#  'annotation_0070.mat',
#  'annotation_0071.mat',
#  'annotation_0072.mat',
#  'annotation_0073.mat',
#  'annotation_0074.mat',
#  'annotation_0075.mat',
#  'annotation_0076.mat',
#  'annotation_0077.mat',
#  'annotation_0078.mat',
#  'annotation_0079.mat',
#  'annotation_0080.mat',
#  'annotation_0081.mat',
#  'annotation_0082.mat',
#  'annotation_0083.mat',
#  'annotation_0084.mat',
#  'annotation_0085.mat',
#  'annotation_0086.mat',
#  'annotation_0087.mat',
#  'annotation_0088.mat',
#  'annotation_0089.mat',
#  'annotation_0090.mat',
#  'annotation_0091.mat',
#  'annotation_0092.mat',
#  'annotation_0093.mat',
#  'annotation_0094.mat',
#  'annotation_0095.mat',
#  'annotation_0096.mat',
#  'annotation_0097.mat',
#  'annotation_0098.mat',
#  'annotation_0099.mat',
#  'annotation_0100.mat',
#  'annotation_0101.mat',
#  'annotation_0102.mat',
#  'annotation_0103.mat',
#  'annotation_0104.mat',
#  'annotation_0105.mat',
#  'annotation_0106.mat',
#  'annotation_0107.mat',
#  'annotation_0108.mat',
#  'annotation_0109.mat',
#  'annotation_0110.mat',
#  'annotation_0111.mat',
#  'annotation_0112.mat',
#  'annotation_0113.mat',
#  'annotation_0114.mat',
#  'annotation_0115.mat',
#  'annotation_0116.mat',
#  'annotation_0117.mat',
#  'annotation_0118.mat',
#  'annotation_0119.mat',
#  'annotation_0120.mat',
#  'annotation_0121.mat',
#  'annotation_0122.mat',
#  'annotation_0123.mat',
#  'annotation_0124.mat',
#  'annotation_0125.mat',
#  'annotation_0126.mat',
#  'annotation_0127.mat',
#  'annotation_0128.mat',
#  'annotation_0129.mat',
#  'annotation_0130.mat',
#  'annotation_0131.mat',
#  'annotation_0132.mat',
#  'annotation_0133.mat',
#  'annotation_0134.mat',
#  'annotation_0135.mat',
#  'annotation_0136.mat',
#  'annotation_0137.mat',
#  'annotation_0138.mat',
#  'annotation_0139.mat',
#  'annotation_0140.mat',
#  'annotation_0141.mat',
#  'annotation_0142.mat',
#  'annotation_0143.mat',
#  'annotation_0144.mat',
#  'annotation_0145.mat',
#  'annotation_0146.mat',
#  'annotation_0147.mat',
#  'annotation_0148.mat',
#  'annotation_0149.mat',
#  'annotation_0150.mat',
#  'annotation_0151.mat',
#  'annotation_0152.mat',
#  'annotation_0153.mat',
#  'annotation_0154.mat',
#  'annotation_0155.mat',
#  'annotation_0156.mat',
#  'annotation_0157.mat',
#  'annotation_0158.mat',
#  'annotation_0159.mat',
#  'annotation_0160.mat',
#  'annotation_0161.mat',
#  'annotation_0162.mat',
#  'annotation_0163.mat',
#  'annotation_0164.mat',
#  'annotation_0165.mat',
#  'annotation_0166.mat',
#  'annotation_0167.mat',
#  'annotation_0168.mat',
#  'annotation_0169.mat',
#  'annotation_0170.mat',
#  'annotation_0171.mat',
#  'annotation_0172.mat',
#  'annotation_0173.mat',
#  'annotation_0174.mat',
#  'annotation_0175.mat',
#  'annotation_0176.mat',
#  'annotation_0177.mat',
#  'annotation_0178.mat',
#  'annotation_0179.mat',
#  'annotation_0180.mat',
#  'annotation_0181.mat',
#  'annotation_0182.mat',
#  'annotation_0183.mat',
#  'annotation_0184.mat',
#  'annotation_0185.mat',
#  'annotation_0186.mat',
#  'annotation_0187.mat',
#  'annotation_0188.mat',
#  'annotation_0189.mat',
#  'annotation_0190.mat',
#  'annotation_0191.mat',
#  'annotation_0192.mat',
#  'annotation_0193.mat',
#  'annotation_0194.mat',
#  'annotation_0195.mat',
#  'annotation_0196.mat',
#  'annotation_0197.mat',
#  'annotation_0198.mat',
#  'annotation_0199.mat',
#  'annotation_0200.mat',
#  'annotation_0201.mat',
#  'annotation_0202.mat',
#  'annotation_0203.mat',
#  'annotation_0204.mat',
#  'annotation_0205.mat',
#  'annotation_0206.mat',
#  'annotation_0207.mat',
#  'annotation_0208.mat',
#  'annotation_0209.mat',
#  'annotation_0210.mat',
#  'annotation_0211.mat',
#  'annotation_0212.mat',
#  'annotation_0213.mat',
#  'annotation_0214.mat',
#  'annotation_0215.mat',
#  'annotation_0216.mat',
#  'annotation_0217.mat',
#  'annotation_0218.mat',
#  'annotation_0219.mat',
#  'annotation_0220.mat',
#  'annotation_0221.mat',
#  'annotation_0222.mat',
#  'annotation_0223.mat',
#  'annotation_0224.mat',
#  'annotation_0225.mat',
#  'annotation_0226.mat',
#  'annotation_0227.mat',
#  'annotation_0228.mat',
#  'annotation_0229.mat',
#  'annotation_0230.mat',
#  'annotation_0231.mat',
#  'annotation_0232.mat',
#  'annotation_0233.mat',
#  'annotation_0234.mat',
#  'annotation_0235.mat',
#  'annotation_0236.mat',
#  'annotation_0237.mat',
#  'annotation_0238.mat',
#  'annotation_0239.mat',
#  'annotation_0240.mat',
#  'annotation_0241.mat',
#  'annotation_0242.mat',
#  'annotation_0243.mat',
#  'annotation_0244.mat',
#  'annotation_0245.mat',
#  'annotation_0246.mat',
#  'annotation_0247.mat',
#  'annotation_0248.mat',
#  'annotation_0249.mat',
#  'annotation_0250.mat',
#  'annotation_0251.mat',
#  'annotation_0252.mat',
#  'annotation_0253.mat',
#  'annotation_0254.mat',
#  'annotation_0255.mat',
#  'annotation_0256.mat',
#  'annotation_0257.mat',
#  'annotation_0258.mat',
#  'annotation_0259.mat',
#  'annotation_0260.mat',
#  'annotation_0261.mat',
#  'annotation_0262.mat',
#  'annotation_0263.mat',
#  'annotation_0264.mat',
#  'annotation_0265.mat',
#  'annotation_0266.mat',
#  'annotation_0267.mat',
#  'annotation_0268.mat',
#  'annotation_0269.mat',
#  'annotation_0270.mat',
#  'annotation_0271.mat',
#  'annotation_0272.mat',
#  'annotation_0273.mat',
#  'annotation_0274.mat',
#  'annotation_0275.mat',
#  'annotation_0276.mat',
#  'annotation_0277.mat',
#  'annotation_0278.mat',
#  'annotation_0279.mat',
#  'annotation_0280.mat',
#  'annotation_0281.mat',
#  'annotation_0282.mat',
#  'annotation_0283.mat',
#  'annotation_0284.mat',
#  'annotation_0285.mat',
#  'annotation_0286.mat',
#  'annotation_0287.mat',
#  'annotation_0288.mat',
#  'annotation_0289.mat',
#  'annotation_0290.mat',
#  'annotation_0291.mat',
#  'annotation_0292.mat',
#  'annotation_0293.mat',
#  'annotation_0294.mat',
#  'annotation_0295.mat',
#  'annotation_0296.mat',
#  'annotation_0297.mat',
#  'annotation_0298.mat',
#  'annotation_0299.mat',
#  'annotation_0300.mat',
#  'annotation_0301.mat',
#  'annotation_0302.mat',
#  'annotation_0303.mat',
#  'annotation_0304.mat',
#  'annotation_0305.mat',
#  'annotation_0306.mat',
#  'annotation_0307.mat',
#  'annotation_0308.mat',
#  'annotation_0309.mat',
#  'annotation_0310.mat',
#  'annotation_0311.mat',
#  'annotation_0312.mat',
#  'annotation_0313.mat',
#  'annotation_0314.mat',
#  'annotation_0315.mat',
#  'annotation_0316.mat',
#  'annotation_0317.mat',
#  'annotation_0318.mat',
#  'annotation_0319.mat',
#  'annotation_0320.mat',
#  'annotation_0321.mat',
#  'annotation_0322.mat',
#  'annotation_0323.mat',
#  'annotation_0324.mat',
#  'annotation_0325.mat',
#  'annotation_0326.mat',
#  'annotation_0327.mat',
#  'annotation_0328.mat',
#  'annotation_0329.mat',
#  'annotation_0330.mat',
#  'annotation_0331.mat',
#  'annotation_0332.mat',
#  'annotation_0333.mat',
#  'annotation_0334.mat',
#  'annotation_0335.mat',
#  'annotation_0336.mat',
#  'annotation_0337.mat',
#  'annotation_0338.mat',
#  'annotation_0339.mat',
#  'annotation_0340.mat',
#  'annotation_0341.mat',
#  'annotation_0342.mat',
#  'annotation_0343.mat',
#  'annotation_0344.mat',
#  'annotation_0345.mat',
#  'annotation_0346.mat',
#  'annotation_0347.mat',
#  'annotation_0348.mat',
#  'annotation_0349.mat',
#  'annotation_0350.mat',
#  'annotation_0351.mat',
#  'annotation_0352.mat',
#  'annotation_0353.mat',
#  'annotation_0354.mat',
#  'annotation_0355.mat',
#  'annotation_0356.mat',
#  'annotation_0357.mat',
#  'annotation_0358.mat',
#  'annotation_0359.mat',
#  'annotation_0360.mat',
#  'annotation_0361.mat',
#  'annotation_0362.mat',
#  'annotation_0363.mat',
#  'annotation_0364.mat',
#  'annotation_0365.mat',
#  'annotation_0366.mat',
#  'annotation_0367.mat',
#  'annotation_0368.mat',
#  'annotation_0369.mat',
#  'annotation_0370.mat',
#  'annotation_0371.mat',
#  'annotation_0372.mat',
#  'annotation_0373.mat',
#  'annotation_0374.mat',
#  'annotation_0375.mat',
#  'annotation_0376.mat',
#  'annotation_0377.mat',
#  'annotation_0378.mat',
#  'annotation_0379.mat',
#  'annotation_0380.mat',
#  'annotation_0381.mat',
#  'annotation_0382.mat',
#  'annotation_0383.mat',
#  'annotation_0384.mat',
#  'annotation_0385.mat',
#  'annotation_0386.mat',
#  'annotation_0387.mat',
#  'annotation_0388.mat',
#  'annotation_0389.mat',
#  'annotation_0390.mat',
#  'annotation_0391.mat',
#  'annotation_0392.mat',
#  'annotation_0393.mat',
#  'annotation_0394.mat',
#  'annotation_0395.mat',
#  'annotation_0396.mat',
#  'annotation_0397.mat',
#  'annotation_0398.mat',
#  'annotation_0399.mat',
#  'annotation_0400.mat',
#  'annotation_0401.mat',
#  'annotation_0402.mat',
#  'annotation_0403.mat',
#  'annotation_0404.mat',
#  'annotation_0405.mat',
#  'annotation_0406.mat',
#  'annotation_0407.mat',
#  'annotation_0408.mat',
#  'annotation_0409.mat',
#  'annotation_0410.mat',
#  'annotation_0411.mat',
#  'annotation_0412.mat',
#  'annotation_0413.mat',
#  'annotation_0414.mat',
#  'annotation_0415.mat',
#  'annotation_0416.mat',
#  'annotation_0417.mat',
#  'annotation_0418.mat',
#  'annotation_0419.mat',
#  'annotation_0420.mat',
#  'annotation_0421.mat',
#  'annotation_0422.mat',
#  'annotation_0423.mat',
#  'annotation_0424.mat',
#  'annotation_0425.mat',
#  'annotation_0426.mat',
#  'annotation_0427.mat',
#  'annotation_0428.mat',
#  'annotation_0429.mat',
#  'annotation_0430.mat',
#  'annotation_0431.mat',
#  'annotation_0432.mat',
#  'annotation_0433.mat',
#  'annotation_0434.mat',
#  'annotation_0435.mat',
#  'annotation_0436.mat',
#  'annotation_0437.mat',
#  'annotation_0438.mat',
#  'annotation_0439.mat',
#  'annotation_0440.mat',
#  'annotation_0441.mat',
#  'annotation_0442.mat',
#  'annotation_0443.mat',
#  'annotation_0444.mat',
#  'annotation_0445.mat',
#  'annotation_0446.mat',
#  'annotation_0447.mat',
#  'annotation_0448.mat',
#  'annotation_0449.mat',
#  'annotation_0450.mat',
#  'annotation_0451.mat',
#  'annotation_0452.mat',
#  'annotation_0453.mat',
#  'annotation_0454.mat',
#  'annotation_0455.mat',
#  'annotation_0456.mat',
#  'annotation_0457.mat',
#  'annotation_0458.mat',
#  'annotation_0459.mat',
#  'annotation_0460.mat',
#  'annotation_0461.mat',
#  'annotation_0462.mat',
#  'annotation_0463.mat',
#  'annotation_0464.mat',
#  'annotation_0465.mat',
#  'annotation_0466.mat',
#  'annotation_0467.mat',
#  'annotation_0468.mat',
#  'annotation_0469.mat',
#  'annotation_0470.mat',
#  'annotation_0471.mat',
#  'annotation_0472.mat',
#  'annotation_0473.mat',
#  'annotation_0474.mat',
#  'annotation_0475.mat',
#  'annotation_0476.mat',
#  'annotation_0477.mat',
#  'annotation_0478.mat',
#  'annotation_0479.mat',
#  'annotation_0480.mat',
#  'annotation_0481.mat',
#  'annotation_0482.mat',
#  'annotation_0483.mat',
#  'annotation_0484.mat',
#  'annotation_0485.mat',
#  'annotation_0486.mat',
#  'annotation_0487.mat',
#  'annotation_0488.mat',
#  'annotation_0489.mat',
#  'annotation_0490.mat',
#  'annotation_0491.mat',
#  'annotation_0492.mat',
#  'annotation_0493.mat',
#  'annotation_0494.mat',
#  'annotation_0495.mat',
#  'annotation_0496.mat',
#  'annotation_0497.mat',
#  'annotation_0498.mat',
#  'annotation_0499.mat',
#  'annotation_0500.mat',
#  'annotation_0501.mat',
#  'annotation_0502.mat',
#  'annotation_0503.mat',
#  'annotation_0504.mat',
#  'annotation_0505.mat',
#  'annotation_0506.mat',
#  'annotation_0507.mat',
#  'annotation_0508.mat',
#  'annotation_0509.mat',
#  'annotation_0510.mat',
#  'annotation_0511.mat',
#  'annotation_0512.mat',
#  'annotation_0513.mat',
#  'annotation_0514.mat',
#  'annotation_0515.mat',
#  'annotation_0516.mat',
#  'annotation_0517.mat',
#  'annotation_0518.mat',
#  'annotation_0519.mat',
#  'annotation_0520.mat',
#  'annotation_0521.mat',
#  'annotation_0522.mat',
#  'annotation_0523.mat',
#  'annotation_0524.mat',
#  'annotation_0525.mat',
#  'annotation_0526.mat',
#  'annotation_0527.mat',
#  'annotation_0528.mat',
#  'annotation_0529.mat',
#  'annotation_0530.mat',
#  'annotation_0531.mat',
#  'annotation_0532.mat',
#  'annotation_0533.mat',
#  'annotation_0534.mat',
#  'annotation_0535.mat',
#  'annotation_0536.mat',
#  'annotation_0537.mat',
#  'annotation_0538.mat',
#  'annotation_0539.mat',
#  'annotation_0540.mat',
#  'annotation_0541.mat',
#  'annotation_0542.mat',
#  'annotation_0543.mat',
#  'annotation_0544.mat',
#  'annotation_0545.mat',
#  'annotation_0546.mat',
#  'annotation_0547.mat',
#  'annotation_0548.mat',
#  'annotation_0549.mat',
#  'annotation_0550.mat',
#  'annotation_0551.mat',
#  'annotation_0552.mat',
#  'annotation_0553.mat',
#  'annotation_0554.mat',
#  'annotation_0555.mat',
#  'annotation_0556.mat',
#  'annotation_0557.mat',
#  'annotation_0558.mat',
#  'annotation_0559.mat',
#  'annotation_0560.mat',
#  'annotation_0561.mat',
#  'annotation_0562.mat',
#  'annotation_0563.mat',
#  'annotation_0564.mat',
#  'annotation_0565.mat',
#  'annotation_0566.mat',
#  'annotation_0567.mat',
#  'annotation_0568.mat',
#  'annotation_0569.mat',
#  'annotation_0570.mat',
#  'annotation_0571.mat',
#  'annotation_0572.mat',
#  'annotation_0573.mat',
#  'annotation_0574.mat',
#  'annotation_0575.mat',
#  'annotation_0576.mat',
#  'annotation_0577.mat',
#  'annotation_0578.mat',
#  'annotation_0579.mat',
#  'annotation_0580.mat',
#  'annotation_0581.mat',
#  'annotation_0582.mat',
#  'annotation_0583.mat',
#  'annotation_0584.mat',
#  'annotation_0585.mat',
#  'annotation_0586.mat',
#  'annotation_0587.mat',
#  'annotation_0588.mat',
#  'annotation_0589.mat',
#  'annotation_0590.mat',
#  'annotation_0591.mat',
#  'annotation_0592.mat',
#  'annotation_0593.mat',
#  'annotation_0594.mat',
#  'annotation_0595.mat',
#  'annotation_0596.mat',
#  'annotation_0597.mat',
#  'annotation_0598.mat',
#  'annotation_0599.mat',
#  'annotation_0600.mat',
#  'annotation_0601.mat',
#  'annotation_0602.mat',
#  'annotation_0603.mat',
#  'annotation_0604.mat',
#  'annotation_0605.mat',
#  'annotation_0606.mat',
#  'annotation_0607.mat',
#  'annotation_0608.mat',
#  'annotation_0609.mat',
#  'annotation_0610.mat',
#  'annotation_0611.mat',
#  'annotation_0612.mat',
#  'annotation_0613.mat',
#  'annotation_0614.mat',
#  'annotation_0615.mat',
#  'annotation_0616.mat',
#  'annotation_0617.mat',
#  'annotation_0618.mat',
#  'annotation_0619.mat',
#  'annotation_0620.mat',
#  'annotation_0621.mat',
#  'annotation_0622.mat',
#  'annotation_0623.mat',
#  'annotation_0624.mat',
#  'annotation_0625.mat',
#  'annotation_0626.mat',
#  'annotation_0627.mat',
#  'annotation_0628.mat',
#  'annotation_0629.mat',
#  'annotation_0630.mat',
#  'annotation_0631.mat',
#  'annotation_0632.mat',
#  'annotation_0633.mat',
#  'annotation_0634.mat',
#  'annotation_0635.mat',
#  'annotation_0636.mat',
#  'annotation_0637.mat',
#  'annotation_0638.mat',
#  'annotation_0639.mat',
#  'annotation_0640.mat',
#  'annotation_0641.mat',
#  'annotation_0642.mat',
#  'annotation_0643.mat',
#  'annotation_0644.mat',
#  'annotation_0645.mat',
#  'annotation_0646.mat',
#  'annotation_0647.mat',
#  'annotation_0648.mat',
#  'annotation_0649.mat',
#  'annotation_0650.mat',
#  'annotation_0651.mat',
#  'annotation_0652.mat',
#  'annotation_0653.mat',
#  'annotation_0654.mat',
#  'annotation_0655.mat',
#  'annotation_0656.mat',
#  'annotation_0657.mat',
#  'annotation_0658.mat',
#  'annotation_0659.mat',
#  'annotation_0660.mat',
#  'annotation_0661.mat',
#  'annotation_0662.mat',
#  'annotation_0663.mat',
#  'annotation_0664.mat',
#  'annotation_0665.mat',
#  'annotation_0666.mat',
#  'annotation_0667.mat',
#  'annotation_0668.mat',
#  'annotation_0669.mat',
#  'annotation_0670.mat',
#  'annotation_0671.mat',
#  'annotation_0672.mat',
#  'annotation_0673.mat',
#  'annotation_0674.mat',
#  'annotation_0675.mat',
#  'annotation_0676.mat',
#  'annotation_0677.mat',
#  'annotation_0678.mat',
#  'annotation_0679.mat',
#  'annotation_0680.mat',
#  'annotation_0681.mat',
#  'annotation_0682.mat',
#  'annotation_0683.mat',
#  'annotation_0684.mat',
#  'annotation_0685.mat',
#  'annotation_0686.mat',
#  'annotation_0687.mat',
#  'annotation_0688.mat',
#  'annotation_0689.mat',
#  'annotation_0690.mat',
#  'annotation_0691.mat',
#  'annotation_0692.mat',
#  'annotation_0693.mat',
#  'annotation_0694.mat',
#  'annotation_0695.mat',
#  'annotation_0696.mat',
#  'annotation_0697.mat',
#  'annotation_0698.mat',
#  'annotation_0699.mat',
#  'annotation_0700.mat',
#  'annotation_0701.mat',
#  'annotation_0702.mat',
#  'annotation_0703.mat',
#  'annotation_0704.mat',
#  'annotation_0705.mat',
#  'annotation_0706.mat',
#  'annotation_0707.mat',
#  'annotation_0708.mat',
#  'annotation_0709.mat',
#  'annotation_0710.mat',
#  'annotation_0711.mat',
#  'annotation_0712.mat',
#  'annotation_0713.mat',
#  'annotation_0714.mat',
#  'annotation_0715.mat',
#  'annotation_0716.mat',
#  'annotation_0717.mat',
#  'annotation_0718.mat',
#  'annotation_0719.mat',
#  'annotation_0720.mat',
#  'annotation_0721.mat',
#  'annotation_0722.mat',
#  'annotation_0723.mat',
#  'annotation_0724.mat',
#  'annotation_0725.mat',
#  'annotation_0726.mat',
#  'annotation_0727.mat',
#  'annotation_0728.mat',
#  'annotation_0729.mat',
#  'annotation_0730.mat',
#  'annotation_0731.mat',
#  'annotation_0732.mat',
#  'annotation_0733.mat',
#  'annotation_0734.mat',
#  'annotation_0735.mat',
#  'annotation_0736.mat',
#  'annotation_0737.mat',
#  'annotation_0738.mat',
#  'annotation_0739.mat',
#  'annotation_0740.mat',
#  'annotation_0741.mat',
#  'annotation_0742.mat',
#  'annotation_0743.mat',
#  'annotation_0744.mat',
#  'annotation_0745.mat',
#  'annotation_0746.mat',
#  'annotation_0747.mat',
#  'annotation_0748.mat',
#  'annotation_0749.mat',
#  'annotation_0750.mat',
#  'annotation_0751.mat',
#  'annotation_0752.mat',
#  'annotation_0753.mat',
#  'annotation_0754.mat',
#  'annotation_0755.mat',
#  'annotation_0756.mat',
#  'annotation_0757.mat',
#  'annotation_0758.mat',
#  'annotation_0759.mat',
#  'annotation_0760.mat',
#  'annotation_0761.mat',
#  'annotation_0762.mat',
#  'annotation_0763.mat',
#  'annotation_0764.mat',
#  'annotation_0765.mat',
#  'annotation_0766.mat',
#  'annotation_0767.mat',
#  'annotation_0768.mat',
#  'annotation_0769.mat',
#  'annotation_0770.mat',
#  'annotation_0771.mat',
#  'annotation_0772.mat',
#  'annotation_0773.mat',
#  'annotation_0774.mat',
#  'annotation_0775.mat',
#  'annotation_0776.mat',
#  'annotation_0777.mat',
#  'annotation_0778.mat',
#  'annotation_0779.mat',
#  'annotation_0780.mat',
#  'annotation_0781.mat',
#  'annotation_0782.mat',
#  'annotation_0783.mat',
#  'annotation_0784.mat',
#  'annotation_0785.mat',
#  'annotation_0786.mat',
#  'annotation_0787.mat',
#  'annotation_0788.mat',
#  'annotation_0789.mat',
#  'annotation_0790.mat',
#  'annotation_0791.mat',
#  'annotation_0792.mat',
#  'annotation_0793.mat',
#  'annotation_0794.mat',
#  'annotation_0795.mat',
#  'annotation_0796.mat',
#  'annotation_0797.mat',
#  'annotation_0798.mat',
#  'annotation_0799.mat',
#  'annotation_0800.mat']

# %%
parties_list = ['alice','bob']

# %%
parties_path_list = []
dataset_name = 'object_detection'
split_dataset_path = os.path.join('.', 'fl-data', dataset_name)
subset_dir = ['images', 'annotation']
for party in parties_list:
    for subset in subset_dir:
        party_path = os.path.join('.', 'fl-data', dataset_name, party, subset)
        os.makedirs(party_path, exist_ok=True)
        parties_path_list.append(party_path)

# %%
parties_path_list
# Out:
# ['./fl-data/object_detection/alice/images',
#  './fl-data/object_detection/alice/annotation',
#  './fl-data/object_detection/bob/images',
#  './fl-data/object_detection/bob/annotation']

# %%
from os.path import join
import shutil

def split_dataset(data_dir_path, file_path_list ,parties_list, dataset_name, subset):
    parties_num = len(parties_list)
    index = 0
    for item_name in file_path_list:
        item_path  = join(data_dir_path, item_name)
        target_dir_path = join('.', 'fl-data', dataset_name, parties_list[index % parties_num ], subset)
        shutil.copy(item_path, target_dir_path)
        print(f'copy {item_path} -->{target_dir_path}')
        index+=1

# %%
split_dataset(path_images, image_paths, parties_list, dataset_name, subset='images')
# Out:
# copy ./101_ObjectCategories/airplanes/image_0001.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0002.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0003.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0004.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0005.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0006.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0007.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0008.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0009.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0010.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0011.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0012.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0013.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0014.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0015.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0016.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0017.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0018.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0019.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0020.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0021.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0022.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0023.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0024.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0025.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0026.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0027.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0028.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0029.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0030.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0031.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0032.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0033.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0034.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0035.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0036.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0037.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0038.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0039.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0040.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0041.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0042.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0043.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0044.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0045.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0046.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0047.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0048.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0049.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0050.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0051.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0052.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0053.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0054.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0055.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0056.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0057.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0058.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0059.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0060.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0061.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0062.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0063.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0064.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0065.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0066.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0067.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0068.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0069.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0070.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0071.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0072.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0073.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0074.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0075.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0076.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0077.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0078.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0079.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0080.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0081.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0082.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0083.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0084.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0085.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0086.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0087.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0088.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0089.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0090.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0091.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0092.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0093.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0094.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0095.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0096.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0097.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0098.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0099.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0100.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0101.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0102.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0103.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0104.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0105.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0106.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0107.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0108.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0109.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0110.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0111.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0112.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0113.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0114.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0115.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0116.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0117.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0118.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0119.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0120.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0121.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0122.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0123.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0124.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0125.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0126.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0127.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0128.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0129.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0130.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0131.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0132.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0133.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0134.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0135.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0136.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0137.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0138.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0139.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0140.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0141.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0142.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0143.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0144.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0145.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0146.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0147.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0148.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0149.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0150.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0151.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0152.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0153.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0154.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0155.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0156.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0157.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0158.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0159.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0160.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0161.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0162.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0163.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0164.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0165.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0166.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0167.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0168.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0169.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0170.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0171.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0172.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0173.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0174.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0175.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0176.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0177.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0178.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0179.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0180.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0181.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0182.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0183.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0184.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0185.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0186.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0187.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0188.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0189.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0190.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0191.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0192.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0193.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0194.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0195.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0196.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0197.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0198.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0199.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0200.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0201.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0202.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0203.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0204.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0205.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0206.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0207.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0208.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0209.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0210.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0211.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0212.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0213.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0214.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0215.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0216.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0217.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0218.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0219.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0220.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0221.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0222.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0223.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0224.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0225.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0226.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0227.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0228.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0229.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0230.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0231.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0232.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0233.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0234.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0235.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0236.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0237.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0238.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0239.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0240.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0241.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0242.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0243.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0244.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0245.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0246.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0247.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0248.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0249.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0250.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0251.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0252.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0253.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0254.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0255.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0256.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0257.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0258.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0259.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0260.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0261.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0262.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0263.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0264.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0265.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0266.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0267.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0268.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0269.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0270.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0271.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0272.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0273.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0274.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0275.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0276.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0277.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0278.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0279.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0280.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0281.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0282.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0283.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0284.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0285.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0286.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0287.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0288.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0289.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0290.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0291.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0292.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0293.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0294.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0295.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0296.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0297.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0298.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0299.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0300.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0301.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0302.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0303.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0304.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0305.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0306.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0307.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0308.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0309.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0310.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0311.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0312.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0313.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0314.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0315.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0316.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0317.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0318.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0319.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0320.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0321.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0322.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0323.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0324.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0325.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0326.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0327.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0328.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0329.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0330.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0331.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0332.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0333.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0334.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0335.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0336.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0337.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0338.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0339.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0340.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0341.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0342.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0343.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0344.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0345.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0346.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0347.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0348.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0349.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0350.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0351.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0352.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0353.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0354.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0355.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0356.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0357.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0358.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0359.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0360.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0361.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0362.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0363.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0364.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0365.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0366.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0367.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0368.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0369.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0370.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0371.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0372.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0373.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0374.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0375.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0376.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0377.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0378.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0379.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0380.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0381.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0382.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0383.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0384.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0385.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0386.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0387.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0388.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0389.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0390.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0391.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0392.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0393.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0394.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0395.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0396.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0397.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0398.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0399.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0400.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0401.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0402.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0403.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0404.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0405.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0406.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0407.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0408.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0409.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0410.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0411.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0412.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0413.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0414.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0415.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0416.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0417.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0418.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0419.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0420.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0421.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0422.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0423.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0424.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0425.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0426.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0427.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0428.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0429.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0430.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0431.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0432.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0433.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0434.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0435.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0436.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0437.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0438.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0439.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0440.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0441.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0442.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0443.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0444.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0445.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0446.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0447.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0448.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0449.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0450.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0451.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0452.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0453.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0454.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0455.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0456.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0457.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0458.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0459.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0460.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0461.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0462.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0463.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0464.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0465.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0466.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0467.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0468.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0469.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0470.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0471.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0472.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0473.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0474.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0475.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0476.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0477.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0478.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0479.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0480.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0481.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0482.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0483.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0484.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0485.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0486.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0487.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0488.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0489.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0490.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0491.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0492.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0493.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0494.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0495.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0496.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0497.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0498.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0499.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0500.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0501.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0502.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0503.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0504.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0505.jpg -->./fl-data/object_detection/alice/images
# ...
# copy ./101_ObjectCategories/airplanes/image_0633.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0634.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0635.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0636.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0637.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0638.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0639.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0640.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0641.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0642.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0643.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0644.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0645.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0646.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0647.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0648.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0649.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0650.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0651.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0652.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0653.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0654.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0655.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0656.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0657.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0658.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0659.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0660.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0661.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0662.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0663.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0664.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0665.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0666.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0667.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0668.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0669.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0670.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0671.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0672.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0673.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0674.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0675.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0676.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0677.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0678.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0679.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0680.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0681.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0682.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0683.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0684.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0685.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0686.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0687.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0688.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0689.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0690.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0691.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0692.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0693.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0694.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0695.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0696.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0697.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0698.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0699.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0700.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0701.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0702.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0703.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0704.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0705.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0706.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0707.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0708.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0709.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0710.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0711.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0712.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0713.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0714.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0715.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0716.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0717.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0718.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0719.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0720.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0721.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0722.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0723.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0724.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0725.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0726.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0727.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0728.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0729.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0730.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0731.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0732.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0733.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0734.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0735.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0736.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0737.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0738.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0739.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0740.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0741.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0742.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0743.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0744.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0745.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0746.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0747.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0748.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0749.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0750.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0751.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0752.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0753.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0754.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0755.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0756.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0757.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0758.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0759.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0760.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0761.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0762.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0763.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0764.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0765.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0766.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0767.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0768.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0769.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0770.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0771.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0772.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0773.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0774.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0775.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0776.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0777.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0778.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0779.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0780.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0781.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0782.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0783.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0784.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0785.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0786.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0787.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0788.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0789.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0790.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0791.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0792.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0793.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0794.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0795.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0796.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0797.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0798.jpg -->./fl-data/object_detection/bob/images
# copy ./101_ObjectCategories/airplanes/image_0799.jpg -->./fl-data/object_detection/alice/images
# copy ./101_ObjectCategories/airplanes/image_0800.jpg -->./fl-data/object_detection/bob/images

# %%
split_dataset(path_annot, annot_paths, parties_list, dataset_name, subset='annotation')
# Out:
# copy ./Annotations/Airplanes_Side_2/annotation_0001.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0002.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0003.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0004.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0005.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0006.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0007.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0008.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0009.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0010.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0011.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0012.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0013.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0014.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0015.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0016.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0017.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0018.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0019.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0020.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0021.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0022.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0023.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0024.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0025.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0026.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0027.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0028.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0029.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0030.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0031.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0032.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0033.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0034.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0035.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0036.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0037.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0038.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0039.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0040.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0041.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0042.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0043.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0044.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0045.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0046.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0047.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0048.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0049.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0050.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0051.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0052.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0053.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0054.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0055.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0056.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0057.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0058.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0059.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0060.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0061.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0062.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0063.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0064.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0065.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0066.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0067.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0068.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0069.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0070.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0071.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0072.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0073.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0074.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0075.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0076.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0077.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0078.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0079.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0080.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0081.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0082.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0083.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0084.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0085.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0086.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0087.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0088.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0089.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0090.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0091.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0092.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0093.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0094.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0095.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0096.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0097.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0098.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0099.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0100.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0101.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0102.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0103.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0104.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0105.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0106.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0107.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0108.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0109.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0110.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0111.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0112.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0113.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0114.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0115.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0116.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0117.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0118.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0119.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0120.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0121.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0122.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0123.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0124.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0125.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0126.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0127.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0128.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0129.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0130.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0131.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0132.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0133.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0134.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0135.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0136.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0137.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0138.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0139.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0140.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0141.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0142.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0143.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0144.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0145.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0146.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0147.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0148.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0149.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0150.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0151.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0152.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0153.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0154.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0155.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0156.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0157.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0158.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0159.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0160.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0161.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0162.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0163.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0164.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0165.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0166.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0167.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0168.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0169.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0170.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0171.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0172.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0173.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0174.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0175.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0176.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0177.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0178.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0179.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0180.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0181.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0182.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0183.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0184.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0185.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0186.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0187.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0188.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0189.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0190.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0191.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0192.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0193.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0194.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0195.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0196.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0197.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0198.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0199.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0200.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0201.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0202.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0203.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0204.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0205.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0206.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0207.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0208.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0209.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0210.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0211.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0212.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0213.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0214.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0215.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0216.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0217.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0218.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0219.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0220.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0221.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0222.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0223.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0224.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0225.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0226.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0227.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0228.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0229.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0230.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0231.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0232.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0233.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0234.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0235.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0236.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0237.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0238.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0239.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0240.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0241.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0242.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0243.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0244.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0245.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0246.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0247.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0248.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0249.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0250.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0251.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0252.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0253.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0254.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0255.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0256.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0257.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0258.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0259.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0260.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0261.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0262.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0263.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0264.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0265.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0266.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0267.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0268.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0269.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0270.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0271.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0272.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0273.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0274.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0275.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0276.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0277.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0278.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0279.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0280.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0281.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0282.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0283.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0284.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0285.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0286.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0287.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0288.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0289.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0290.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0291.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0292.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0293.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0294.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0295.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0296.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0297.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0298.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0299.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0300.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0301.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0302.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0303.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0304.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0305.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0306.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0307.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0308.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0309.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0310.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0311.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0312.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0313.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0314.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0315.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0316.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0317.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0318.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0319.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0320.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0321.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0322.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0323.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0324.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0325.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0326.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0327.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0328.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0329.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0330.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0331.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0332.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0333.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0334.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0335.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0336.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0337.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0338.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0339.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0340.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0341.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0342.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0343.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0344.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0345.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0346.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0347.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0348.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0349.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0350.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0351.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0352.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0353.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0354.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0355.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0356.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0357.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0358.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0359.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0360.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0361.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0362.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0363.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0364.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0365.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0366.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0367.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0368.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0369.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0370.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0371.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0372.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0373.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0374.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0375.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0376.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0377.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0378.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0379.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0380.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0381.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0382.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0383.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0384.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0385.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0386.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0387.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0388.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0389.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0390.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0391.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0392.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0393.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0394.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0395.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0396.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0397.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0398.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0399.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0400.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0401.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0402.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0403.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0404.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0405.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0406.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0407.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0408.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0409.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0410.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0411.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0412.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0413.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0414.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0415.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0416.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0417.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0418.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0419.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0420.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0421.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0422.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0423.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0424.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0425.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0426.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0427.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0428.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0429.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0430.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0431.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0432.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0433.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0434.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0435.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0436.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0437.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0438.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0439.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0440.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0441.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0442.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0443.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0444.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0445.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0446.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0447.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0448.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0449.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0450.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0451.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0452.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0453.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0454.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0455.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0456.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0457.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0458.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0459.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0460.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0461.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0462.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0463.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0464.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0465.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0466.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0467.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0468.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0469.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0470.mat -->./fl-data/object_detection/bob/annotation
# ...
# copy ./Annotations/Airplanes_Side_2/annotation_0645.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0646.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0647.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0648.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0649.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0650.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0651.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0652.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0653.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0654.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0655.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0656.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0657.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0658.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0659.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0660.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0661.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0662.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0663.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0664.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0665.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0666.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0667.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0668.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0669.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0670.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0671.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0672.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0673.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0674.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0675.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0676.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0677.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0678.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0679.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0680.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0681.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0682.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0683.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0684.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0685.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0686.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0687.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0688.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0689.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0690.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0691.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0692.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0693.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0694.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0695.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0696.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0697.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0698.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0699.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0700.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0701.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0702.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0703.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0704.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0705.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0706.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0707.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0708.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0709.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0710.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0711.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0712.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0713.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0714.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0715.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0716.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0717.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0718.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0719.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0720.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0721.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0722.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0723.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0724.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0725.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0726.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0727.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0728.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0729.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0730.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0731.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0732.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0733.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0734.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0735.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0736.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0737.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0738.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0739.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0740.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0741.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0742.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0743.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0744.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0745.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0746.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0747.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0748.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0749.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0750.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0751.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0752.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0753.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0754.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0755.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0756.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0757.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0758.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0759.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0760.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0761.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0762.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0763.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0764.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0765.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0766.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0767.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0768.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0769.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0770.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0771.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0772.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0773.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0774.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0775.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0776.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0777.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0778.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0779.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0780.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0781.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0782.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0783.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0784.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0785.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0786.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0787.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0788.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0789.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0790.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0791.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0792.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0793.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0794.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0795.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0796.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0797.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0798.mat -->./fl-data/object_detection/bob/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0799.mat -->./fl-data/object_detection/alice/annotation
# copy ./Annotations/Airplanes_Side_2/annotation_0800.mat -->./fl-data/object_detection/bob/annotation

# %% [markdown]
# ### 自定义Dataloader

# %%
def create_dataset_builder(
    batch_size=32,
):
    def dataset_builder(folder_path, stage="train"):
        import math

        import tensorflow as tf
        # get the path of dataset
        path_images = os.path.join(folder_path, 'images')
        path_annot = os.path.join(folder_path, 'annotation')
        # list of paths to images and annotations
        image_paths = [
            f for f in os.listdir(path_images) if os.path.isfile(os.path.join(path_images, f))
        ]
        annot_paths = [
            f for f in os.listdir(path_annot) if os.path.isfile(os.path.join(path_annot, f))
        ]

        image_paths.sort()
        annot_paths.sort()

        image_size = 224  # resize input images to this size

        images, targets = [], []

        # loop over the annotations and images, preprocess them and store in lists
        for i in range(0, len(annot_paths)):
            # Access bounding box coordinates
            annot = scipy.io.loadmat(os.path.join(path_annot , annot_paths[i]))["box_coord"][0]

            top_left_x, top_left_y = annot[2], annot[0]
            bottom_right_x, bottom_right_y = annot[3], annot[1]

            image = keras.utils.load_img(
                os.path.join(path_images , image_paths[i]),
            )
        (w, h) = image.size[:2]

        # In order to form data generator to evaluate model conveniently
        # we resize the whole dataset which is differe with example from keras
        image = image.resize((image_size, image_size))

        # convert image to array and append to list
        images.append(keras.utils.img_to_array(image))

        # apply relative scaling to bounding boxes as per given image and append to list
        targets.append(
            (
                float(top_left_x) / w,
                float(top_left_y) / h,
                float(bottom_right_x) / w,
                float(bottom_right_y) / h,
            )
        )

        # Convert the list to numpy array, split to train and test dataset
        (x_train), (y_train) = (
            np.asarray(images[: int(len(images) * 0.9)]),
            np.asarray(targets[: int(len(targets) * 0.9)]),
        )
        (x_eval), (y_eval) = (
            np.asarray(images[int(len(images) * 0.9) :]),
            np.asarray(targets[int(len(targets) * 0.9) :]),
        )

        train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
        eval_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

        SHUFFLE_BUFFER_SIZE = 1024
        train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(batch_size)
        eval_dataset = eval_dataset.batch(batch_size)

        if stage == "train":
            train_step_per_epoch = math.ceil(x_train.shape[0] / batch_size)
            return train_dataset, train_step_per_epoch
        elif stage == "eval":
            eval_step_per_epoch = math.ceil(x_test.shape[0] / batch_size)
            return eval_dataset, eval_step_per_epoch

    return dataset_builder

# %%
import secretflow as sf

# Check the version of your SecretFlow
print('The version of SecretFlow: {}'.format(sf.__version__))

# In case you have a running secretflow runtime already.
sf.shutdown()
sf.init(['alice', 'bob', 'charlie'], address="local", log_to_driver=False)
alice, bob, charlie = sf.PYU('alice'), sf.PYU('bob'), sf.PYU('charlie')
# Out:
# WARNING: Fail to define brpc::ENOSERVICE(1001) which is already defined as `未知的错误 1001'WARNING: Fail to define brpc::ENOMETHOD(1002) which is already defined as `未知的错误 1002'WARNING: Fail to define brpc::EREQUEST(1003) which is already defined as `未知的错误 1003'WARNING: Fail to define brpc::ERPCAUTH(1004) which is already defined as `未知的错误 1004'WARNING: Fail to define brpc::ETOOMANYFAILS(1005) which is already defined as `未知的错误 1005'WARNING: Fail to define brpc::EPCHANFINISH(1006) which is already defined as `未知的错误 1006'WARNING: Fail to define brpc::EBACKUPREQUEST(1007) which is already defined as `未知的错误 1007'WARNING: Fail to define brpc::ERPCTIMEDOUT(1008) which is already defined as `未知的错误 1008'WARNING: Fail to define brpc::EFAILEDSOCKET(1009) which is already defined as `未知的错误 1009'WARNING: Fail to define brpc::EHTTP(1010) which is already defined as `未知的错误 1010'WARNING: Fail to define brpc::EOVERCROWDED(1011) which is already defined as `未知的错误 1011'WARNING: Fail to define brpc::ERTMPPUBLISHABLE(1012) which is already defined as `未知的错误 1012'WARNING: Fail to define brpc::ERTMPCREATESTREAM(1013) which is already defined as `未知的错误 1013'WARNING: Fail to define brpc::EEOF(1014) which is already defined as `未知的错误 1014'WARNING: Fail to define brpc::EUNUSED(1015) which is already defined as `未知的错误 1015'WARNING: Fail to define brpc::ESSL(1016) which is already defined as `未知的错误 1016'WARNING: Fail to define brpc::EH2RUNOUTSTREAMS(1017) which is already defined as `未知的错误 1017'WARNING: Fail to define brpc::EINTERNAL(2001) which is already defined as `未知的错误 2001'WARNING: Fail to define brpc::ERESPONSE(2002) which is already defined as `未知的错误 2002'WARNING: Fail to define brpc::ELOGOFF(2003) which is already defined as `未知的错误 2003'WARNING: Fail to define brpc::ELIMIT(2004) which is already defined as `未知的错误 2004'WARNING: Fail to define brpc::ECLOSE(2005) which is already defined as `未知的错误 2005'WARNING: Fail to define brpc::EITP(2006) which is already defined as `未知的错误 2006'WARNING: Fail to define ESTOP(-20) which is already defined as `未知的错误 -20'
# The version of SecretFlow: 1.1.0.dev20230822
# 2023-09-02 11:54:19,593	INFO worker.py:1538 -- Started a local Ray instance.

# %%
data_builder_dict = {
    alice: create_dataset_builder(
        batch_size=32,
    ),
    bob: create_dataset_builder(
        batch_size=32,
    ),
}

# %%
def create_fl_vit_object_detector(input_shape,
    patch_size,
    num_patches,
    projection_dim,
    num_heads,
    transformer_units,
    transformer_layers,
    mlp_head_units,):
    def create_model():
        model = create_vit_object_detector(
    input_shape,
    patch_size,
    num_patches,
    projection_dim,
    num_heads,
    transformer_units,
    transformer_layers,
    mlp_head_units,
)

        optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay)

        # Compile model.
        model.compile(optimizer=optimizer, loss=keras.losses.MeanSquaredError())
        
        return model
    return create_model

# %%
from secretflow.ml.nn import FLModel
from secretflow.security.aggregation import SecureAggregator

# %%
device_list = [alice, bob]
aggregator = SecureAggregator(charlie, [alice, bob])

# prepare model
image_size = 224
input_shape = (image_size, image_size, 3)  # input image shape
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 32
num_epochs = 10
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
# Size of the transformer layers
transformer_units = [
    projection_dim * 2,
    projection_dim,
]
transformer_layers = 4
mlp_head_units = [2048, 1024, 512, 64, 32]  # Size of the dense layers


history = []
num_patches = (image_size // patch_size) ** 2

# keras model
model = create_fl_vit_object_detector(input_shape,
    patch_size,
    num_patches,
    projection_dim,
    num_heads,
    transformer_units,
    transformer_layers,
    mlp_head_units,)


fed_model = FLModel(
    device_list=device_list,
    model=model,
    aggregator=aggregator,
    backend="tensorflow",
    strategy="fed_avg_w",
    random_seed=1234,
)
# Out:
# INFO:root:Create proxy actor <class 'secretflow.security.aggregation.secure_aggregator._Masker'> with party alice.
# INFO:root:Create proxy actor <class 'secretflow.security.aggregation.secure_aggregator._Masker'> with party bob.
# INFO:root:Create proxy actor <class 'secretflow.ml.nn.fl.backend.tensorflow.strategy.fed_avg_w.PYUFedAvgW'> with party alice.
# INFO:root:Create proxy actor <class 'secretflow.ml.nn.fl.backend.tensorflow.strategy.fed_avg_w.PYUFedAvgW'> with party bob.

# %%
data = {
    alice: './fl-data/object_detection/alice',
    bob: './fl-data/object_detection/bob',
}


checkpoint_filepath = "logs/"
checkpoint_callback = keras.callbacks.ModelCheckpoint(
    checkpoint_filepath,
    monitor="val_loss",
    save_best_only=True,
    save_weights_only=True,
)

history = fed_model.fit(
    data,
    None,
    validation_data=data,
    epochs=5,
    batch_size=32,
    aggregate_freq=2,
    sampler_method="batch",
    random_seed=1234,
    dp_spent_step_freq=1,
    dataset_builder=data_builder_dict,
    callbacks=[
    checkpoint_callback,
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=10),
    ],
)
# Out:
# INFO:root:FL Train Params: {'self': <secretflow.ml.nn.fl.fl_model.FLModel object at 0x7fe968430340>, 'x': {PYURuntime(alice): './fl-data/object_detection/alice', PYURuntime(bob): './fl-data/object_detection/bob'}, 'y': None, 'batch_size': 32, 'batch_sampling_rate': None, 'epochs': 5, 'verbose': 1, 'callbacks': [<keras.callbacks.ModelCheckpoint object at 0x7fe7ef232490>, <keras.callbacks.EarlyStopping object at 0x7fe7ef232430>], 'validation_data': {PYURuntime(alice): './fl-data/object_detection/alice', PYURuntime(bob): './fl-data/object_detection/bob'}, 'shuffle': False, 'class_weight': None, 'sample_weight': None, 'validation_freq': 1, 'aggregate_freq': 2, 'label_decoder': None, 'max_batch_size': 20000, 'prefetch_buffer_size': None, 'sampler_method': 'batch', 'random_seed': 1234, 'dp_spent_step_freq': 1, 'audit_log_dir': None, 'dataset_builder': {PYURuntime(alice): <function create_dataset_builder.<locals>.dataset_builder at 0x7fe8d45439d0>, PYURuntime(bob): <function create_dataset_builder.<locals>.dataset_builder at 0x7fe8007a28b0>}, 'wait_steps': 100}
# ---------------------------------------------------------------------------
# RayTaskError(ValueError)                  Traceback (most recent call last)
# Cell In[42], line 15
#       7 checkpoint_filepath = "logs/"
#       8 checkpoint_callback = keras.callbacks.ModelCheckpoint(
#       9     checkpoint_filepath,
#      10     monitor="val_loss",
#      11     save_best_only=True,
#      12     save_weights_only=True,
#      13 )
# ---> 15 history = fed_model.fit(
#      16     data,
#      17     None,
#      18     validation_data=data,
#      19     epochs=5,
#      20     batch_size=32,
#      21     aggregate_freq=2,
#      22     sampler_method="batch",
#      23     random_seed=1234,
#      24     dp_spent_step_freq=1,
#      25     dataset_builder=data_builder_dict,
#      26     callbacks=[
#      27     checkpoint_callback,
#      28     keras.callbacks.EarlyStopping(monitor="val_loss", patience=10),
#      29     ],
#      30 )
#
# File ~/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/secretflow/ml/nn/fl/fl_model.py:379, in FLModel.fit(self, x, y, batch_size, batch_sampling_rate, epochs, verbose, callbacks, validation_data, shuffle, class_weight, sample_weight, validation_freq, aggregate_freq, label_decoder, max_batch_size, prefetch_buffer_size, sampler_method, random_seed, dp_spent_step_freq, audit_log_dir, dataset_builder, wait_steps)
#     376     else:
#     377         valid_x, valid_y = None, None
# --> 379     self._handle_file(
#     380         x,
#     381         y,
#     382         batch_size=batch_size,
#     383         sampling_rate=batch_sampling_rate,
#     384         shuffle=shuffle,
#     385         random_seed=random_seed,
#     386         epochs=epochs,
#     387         label_decoder=label_decoder,
#     388         max_batch_size=max_batch_size,
#     389         prefetch_buffer_size=prefetch_buffer_size,
#     390         dataset_builder=dataset_builder,
#     391     )
#     392 else:
#     393     assert type(x) == type(y), "x and y must be same data type"
#
# File ~/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/secretflow/ml/nn/fl/fl_model.py:150, in FLModel._handle_file(self, train_dict, label, batch_size, sampling_rate, shuffle, random_seed, epochs, stage, label_decoder, max_batch_size, prefetch_buffer_size, dataset_builder)
#     141     steps_per_epoch = worker.build_dataset_from_builder(
#     142         dataset_builder[device],
#     143         train_dict[device],
#    (...)
#     147         repeat_count=epochs,
#     148     )
#     149     steps_per_epochs.append(steps_per_epoch)
# --> 150 set_steps_per_epochs = set(reveal(steps_per_epochs))
#     151 assert (
#     152     len(set_steps_per_epochs) == 1
#     153 ), "steps_per_epochs of all parties must be same"
#     154 self.steps_per_epoch = set_steps_per_epochs.pop()
#
# File ~/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/secretflow/device/driver.py:162, in reveal(func_or_object, heu_encoder)
#     159         logging.debug(f'Getting teeu data from TEEU {x.device.party}.')
#     161 cur_idx = 0
# --> 162 all_object = sfd.get(all_object_refs)
#     164 new_flatten_val = []
#     165 for x in flatten_val:
#
# File ~/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/secretflow/distributed/primitive.py:75, in get(object_refs)
#      73     return fed.get(object_refs)
#      74 else:
# ---> 75     return ray.get(object_refs)
#
# File ~/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/ray/_private/client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     103     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/ray/_private/worker.py:2309, in get(object_refs, timeout)
#    2307     worker.core_worker.dump_object_store_memory_usage()
#    2308 if isinstance(value, RayTaskError):
# -> 2309     raise value.as_instanceof_cause()
#    2310 else:
#    2311     raise value
#
# RayTaskError(ValueError): ray::PYUFedAvgW.build_dataset_from_builder() (pid=990782, ip=59.77.13.166, repr=<secretflow.ml.nn.fl.backend.tensorflow.strategy.fed_avg_w.PYUFedAvgW object at 0x7efda48cb280>)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/secretflow/device/proxy.py", line 79, in wrapper
#     return method(*args, **kwargs)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/secretflow/ml/nn/fl/backend/tensorflow/fl_base.py", line 187, in build_dataset_from_builder
#     data_set, step_per_epoch = dataset_builder(x, stage=stage)
#   File "/tmp/ipykernel_987583/945081539.py", line 67, in dataset_builder
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 818, in from_tensor_slices
#     return from_tensor_slices_op.from_tensor_slices(tensors, name)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/data/ops/from_tensor_slices_op.py", line 25, in from_tensor_slices
#     return TensorSliceDataset(tensors, name=name)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/data/ops/from_tensor_slices_op.py", line 33, in __init__
#     element = structure.normalize_element(element)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/data/util/structure.py", line 130, in normalize_element
#     ops.convert_to_tensor(t, name="component_%d" % i, dtype=dtype))
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py", line 183, in wrapped
#     return func(*args, **kwargs)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 1636, in convert_to_tensor
#     ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/framework/tensor_conversion_registry.py", line 48, in _default_conversion_function
#     return constant_op.constant(value, dtype, name=name)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py", line 267, in constant
#     return _constant_impl(value, dtype, shape, name, verify_shape=False,
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py", line 279, in _constant_impl
#     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py", line 304, in _constant_eager_impl
#     t = convert_to_eager_tensor(value, ctx, dtype)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py", line 102, in convert_to_eager_tensor
#     return ops.EagerTensor(value, ctx.device_name, dtype)
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type numpy.ndarray).
# 2023-09-02 11:54:36,134	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::PYUFedAvgW.build_dataset_from_builder() (pid=990784, ip=59.77.13.166, repr=<secretflow.ml.nn.fl.backend.tensorflow.strategy.fed_avg_w.PYUFedAvgW object at 0x7f676074b220>)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/secretflow/device/proxy.py", line 79, in wrapper
#     return method(*args, **kwargs)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/secretflow/ml/nn/fl/backend/tensorflow/fl_base.py", line 187, in build_dataset_from_builder
#     data_set, step_per_epoch = dataset_builder(x, stage=stage)
#   File "/tmp/ipykernel_987583/945081539.py", line 67, in dataset_builder
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 818, in from_tensor_slices
#     return from_tensor_slices_op.from_tensor_slices(tensors, name)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/data/ops/from_tensor_slices_op.py", line 25, in from_tensor_slices
#     return TensorSliceDataset(tensors, name=name)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/data/ops/from_tensor_slices_op.py", line 33, in __init__
#     element = structure.normalize_element(element)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/data/util/structure.py", line 130, in normalize_element
#     ops.convert_to_tensor(t, name="component_%d" % i, dtype=dtype))
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py", line 183, in wrapped
#     return func(*args, **kwargs)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 1636, in convert_to_tensor
#     ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/framework/tensor_conversion_registry.py", line 48, in _default_conversion_function
#     return constant_op.constant(value, dtype, name=name)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py", line 267, in constant
#     return _constant_impl(value, dtype, shape, name, verify_shape=False,
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py", line 279, in _constant_impl
#     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py", line 304, in _constant_eager_impl
#     t = convert_to_eager_tensor(value, ctx, dtype)
#   File "/home/sunwen/anaconda3/envs/luoyelab_oscp/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py", line 102, in convert_to_eager_tensor
#     return ops.EagerTensor(value, ctx.device_name, dtype)
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type numpy.ndarray).
